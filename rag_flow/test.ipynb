# %%
# !pip install FlagEmbedding==1.3.5
# Out:
# Collecting FlagEmbedding==1.3.5
#   Using cached flagembedding-1.3.5-py3-none-any.whl
# Collecting torch>=1.6.0 (from FlagEmbedding==1.3.5)
#   Using cached torch-2.2.2-cp311-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting transformers>=4.44.2 (from FlagEmbedding==1.3.5)
#   Using cached transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Collecting datasets>=2.19.0 (from FlagEmbedding==1.3.5)
#   Downloading datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
# Collecting accelerate>=0.20.1 (from FlagEmbedding==1.3.5)
#   Using cached accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Collecting sentence_transformers (from FlagEmbedding==1.3.5)
#   Using cached sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Collecting peft (from FlagEmbedding==1.3.5)
#   Using cached peft-0.17.1-py3-none-any.whl.metadata (14 kB)
# Collecting ir-datasets (from FlagEmbedding==1.3.5)
#   Using cached ir_datasets-0.5.11-py3-none-any.whl.metadata (12 kB)
# Collecting sentencepiece (from FlagEmbedding==1.3.5)
#   Using cached sentencepiece-0.2.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (10 kB)
# Collecting protobuf (from FlagEmbedding==1.3.5)
#   Using cached protobuf-6.33.0-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting numpy>=1.17 (from accelerate>=0.20.1->FlagEmbedding==1.3.5)
#   Using cached numpy-2.3.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/taeni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from accelerate>=0.20.1->FlagEmbedding==1.3.5) (25.0)
# Requirement already satisfied: psutil in /Users/taeni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from accelerate>=0.20.1->FlagEmbedding==1.3.5) (7.1.3)
# Collecting pyyaml (from accelerate>=0.20.1->FlagEmbedding==1.3.5)
#   Using cached pyyaml-6.0.3-cp311-cp311-macosx_10_13_x86_64.whl.metadata (2.4 kB)
# Collecting huggingface_hub>=0.21.0 (from accelerate>=0.20.1->FlagEmbedding==1.3.5)
#   Downloading huggingface_hub-1.1.2-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate>=0.20.1->FlagEmbedding==1.3.5)
#   Using cached safetensors-0.6.2-cp38-abi3-macosx_10_12_x86_64.whl.metadata (4.1 kB)
# Collecting filelock (from datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pyarrow>=21.0.0 (from datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached pyarrow-22.0.0-cp311-cp311-macosx_12_0_x86_64.whl.metadata (3.1 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached pandas-2.3.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (91 kB)
# Collecting requests>=2.32.2 (from datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting httpx<1.0.0 (from datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting tqdm>=4.66.3 (from datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached xxhash-3.6.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Downloading multiprocess-0.70.18-py311-none-any.whl.metadata (7.5 kB)
# Collecting fsspec<=2025.10.0,>=2023.1.0 (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached aiohttp-3.13.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.1 kB)
# Collecting anyio (from httpx<1.0.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting certifi (from httpx<1.0.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1.0.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1.0.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface_hub>=0.21.0->accelerate>=0.20.1->FlagEmbedding==1.3.5)
#   Using cached hf_xet-1.2.0-cp37-abi3-macosx_10_12_x86_64.whl.metadata (4.9 kB)
# Collecting shellingham (from huggingface_hub>=0.21.0->accelerate>=0.20.1->FlagEmbedding==1.3.5)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting typer-slim (from huggingface_hub>=0.21.0->accelerate>=0.20.1->FlagEmbedding==1.3.5)
#   Downloading typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/taeni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate>=0.20.1->FlagEmbedding==1.3.5) (4.15.0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached frozenlist-1.8.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached multidict-6.7.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached propcache-0.4.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached yarl-1.22.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (75 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.32.2->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl.metadata (37 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.32.2->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting sympy (from torch>=1.6.0->FlagEmbedding==1.3.5)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.6.0->FlagEmbedding==1.3.5)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.6.0->FlagEmbedding==1.3.5)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface_hub>=0.21.0 (from accelerate>=0.20.1->FlagEmbedding==1.3.5)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Collecting regex!=2019.12.17 (from transformers>=4.44.2->FlagEmbedding==1.3.5)
#   Downloading regex-2025.11.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers>=4.44.2->FlagEmbedding==1.3.5)
#   Using cached tokenizers-0.22.1-cp39-abi3-macosx_10_12_x86_64.whl.metadata (6.8 kB)
# Collecting sniffio>=1.1 (from anyio->httpx<1.0.0->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting beautifulsoup4>=4.4.1 (from ir-datasets->FlagEmbedding==1.3.5)
#   Using cached beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting inscriptis>=2.2.0 (from ir-datasets->FlagEmbedding==1.3.5)
#   Using cached inscriptis-2.6.0-py3-none-any.whl.metadata (25 kB)
# Collecting lxml>=4.5.2 (from ir-datasets->FlagEmbedding==1.3.5)
#   Using cached lxml-6.0.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.6 kB)
# Collecting trec-car-tools>=2.5.4 (from ir-datasets->FlagEmbedding==1.3.5)
#   Using cached trec_car_tools-2.6-py3-none-any.whl.metadata (640 bytes)
# Collecting lz4>=3.1.10 (from ir-datasets->FlagEmbedding==1.3.5)
#   Downloading lz4-4.4.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.8 kB)
# Collecting warc3-wet>=0.2.3 (from ir-datasets->FlagEmbedding==1.3.5)
#   Using cached warc3_wet-0.2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir-datasets->FlagEmbedding==1.3.5)
#   Using cached warc3_wet_clueweb09-0.2.5-py3-none-any.whl
# Collecting zlib-state>=0.1.3 (from ir-datasets->FlagEmbedding==1.3.5)
#   Using cached zlib_state-0.1.10-cp311-cp311-macosx_12_0_x86_64.whl
# Collecting ijson>=3.1.3 (from ir-datasets->FlagEmbedding==1.3.5)
#   Using cached ijson-3.4.0.post0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (23 kB)
# Collecting unlzw3>=0.2.1 (from ir-datasets->FlagEmbedding==1.3.5)
#   Using cached unlzw3-0.2.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.4.1->ir-datasets->FlagEmbedding==1.3.5)
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir-datasets->FlagEmbedding==1.3.5)
#   Using cached cbor-1.0.0-cp311-cp311-macosx_12_0_x86_64.whl
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.6.0->FlagEmbedding==1.3.5)
#   Using cached markupsafe-3.0.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/taeni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas->datasets>=2.19.0->FlagEmbedding==1.3.5) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets>=2.19.0->FlagEmbedding==1.3.5)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/taeni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.19.0->FlagEmbedding==1.3.5) (1.17.0)
# Collecting scikit-learn (from sentence_transformers->FlagEmbedding==1.3.5)
#   Using cached scikit_learn-1.7.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (11 kB)
# Collecting scipy (from sentence_transformers->FlagEmbedding==1.3.5)
#   Using cached scipy-1.16.3-cp311-cp311-macosx_10_14_x86_64.whl.metadata (62 kB)
# Collecting Pillow (from sentence_transformers->FlagEmbedding==1.3.5)
#   Using cached pillow-12.0.0-cp311-cp311-macosx_10_10_x86_64.whl.metadata (8.8 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence_transformers->FlagEmbedding==1.3.5)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence_transformers->FlagEmbedding==1.3.5)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.6.0->FlagEmbedding==1.3.5)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting click>=8.0.0 (from typer-slim->huggingface_hub>=0.21.0->accelerate>=0.20.1->FlagEmbedding==1.3.5)
#   Using cached click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Using cached accelerate-1.11.0-py3-none-any.whl (375 kB)
# Downloading datasets-4.4.1-py3-none-any.whl (511 kB)
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached hf_xet-1.2.0-cp37-abi3-macosx_10_12_x86_64.whl (2.9 MB)
# Downloading multiprocess-0.70.18-py311-none-any.whl (144 kB)
# Using cached aiohttp-3.13.2-cp311-cp311-macosx_10_9_x86_64.whl (497 kB)
# Using cached multidict-6.7.0-cp311-cp311-macosx_10_9_x86_64.whl (44 kB)
# Using cached yarl-1.22.0-cp311-cp311-macosx_10_9_x86_64.whl (94 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Using cached frozenlist-1.8.0-cp311-cp311-macosx_10_9_x86_64.whl (50 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached numpy-2.3.4-cp311-cp311-macosx_10_9_x86_64.whl (21.3 MB)
# Using cached propcache-0.4.1-cp311-cp311-macosx_10_9_x86_64.whl (45 kB)
# Using cached pyarrow-22.0.0-cp311-cp311-macosx_12_0_x86_64.whl (36.0 MB)
# Using cached pyyaml-6.0.3-cp311-cp311-macosx_10_13_x86_64.whl (185 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl (206 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Using cached safetensors-0.6.2-cp38-abi3-macosx_10_12_x86_64.whl (454 kB)
# Using cached torch-2.2.2-cp311-none-macosx_10_9_x86_64.whl (150.8 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached transformers-4.57.1-py3-none-any.whl (12.0 MB)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Using cached tokenizers-0.22.1-cp39-abi3-macosx_10_12_x86_64.whl (3.1 MB)
# Downloading regex-2025.11.3-cp311-cp311-macosx_10_9_x86_64.whl (290 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Using cached ir_datasets-0.5.11-py3-none-any.whl (866 kB)
# Using cached beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Using cached ijson-3.4.0.post0-cp311-cp311-macosx_10_9_x86_64.whl (59 kB)
# Using cached inscriptis-2.6.0-py3-none-any.whl (45 kB)
# Using cached lxml-6.0.2-cp311-cp311-macosx_10_9_x86_64.whl (4.7 MB)
# Downloading lz4-4.4.5-cp311-cp311-macosx_10_9_x86_64.whl (207 kB)
# Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Using cached trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Using cached unlzw3-0.2.3-py3-none-any.whl (6.7 kB)
# Using cached warc3_wet-0.2.5-py3-none-any.whl (18 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp311-cp311-macosx_10_9_x86_64.whl (11 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Using cached pandas-2.3.3-cp311-cp311-macosx_10_9_x86_64.whl (11.6 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached peft-0.17.1-py3-none-any.whl (504 kB)
# Using cached protobuf-6.33.0-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
# Using cached pillow-12.0.0-cp311-cp311-macosx_10_10_x86_64.whl (5.3 MB)
# Using cached scikit_learn-1.7.2-cp311-cp311-macosx_10_9_x86_64.whl (9.3 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached scipy-1.16.3-cp311-cp311-macosx_10_14_x86_64.whl (36.6 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached sentencepiece-0.2.1-cp311-cp311-macosx_10_9_x86_64.whl (1.3 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached xxhash-3.6.0-cp311-cp311-macosx_10_9_x86_64.whl (32 kB)
# Installing collected packages: warc3-wet-clueweb09, warc3-wet, pytz, mpmath, cbor, zlib-state, xxhash, urllib3, unlzw3, tzdata, tqdm, threadpoolctl, sympy, soupsieve, sniffio, sentencepiece, safetensors, regex, pyyaml, pyarrow, protobuf, propcache, Pillow, numpy, networkx, multidict, MarkupSafe, lz4, lxml, joblib, ijson, idna, hf-xet, h11, fsspec, frozenlist, filelock, dill, charset_normalizer, certifi, attrs, aiohappyeyeballs, yarl, trec-car-tools, scipy, requests, pandas, multiprocess, jinja2, httpcore, beautifulsoup4, anyio, aiosignal, torch, scikit-learn, inscriptis, huggingface_hub, httpx, aiohttp, tokenizers, ir-datasets, accelerate, transformers, datasets, sentence_transformers, peft, FlagEmbedding
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67/67 [FlagEmbedding]mbedding]nce_transformers]
# Successfully installed FlagEmbedding-1.3.5 MarkupSafe-3.0.3 Pillow-12.0.0 accelerate-1.11.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 anyio-4.11.0 attrs-25.4.0 beautifulsoup4-4.14.2 cbor-1.0.0 certifi-2025.10.5 charset_normalizer-3.4.4 datasets-4.4.1 dill-0.4.0 filelock-3.20.0 frozenlist-1.8.0 fsspec-2025.10.0 h11-0.16.0 hf-xet-1.2.0 httpcore-1.0.9 httpx-0.28.1 huggingface_hub-0.36.0 idna-3.11 ijson-3.4.0.post0 inscriptis-2.6.0 ir-datasets-0.5.11 jinja2-3.1.6 joblib-1.5.2 lxml-6.0.2 lz4-4.4.5 mpmath-1.3.0 multidict-6.7.0 multiprocess-0.70.18 networkx-3.5 numpy-2.3.4 pandas-2.3.3 peft-0.17.1 propcache-0.4.1 protobuf-6.33.0 pyarrow-22.0.0 pytz-2025.2 pyyaml-6.0.3 regex-2025.11.3 requests-2.32.5 safetensors-0.6.2 scikit-learn-1.7.2 scipy-1.16.3 sentence_transformers-5.1.2 sentencepiece-0.2.1 sniffio-1.3.1 soupsieve-2.8 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.22.1 torch-2.2.2 tqdm-4.67.1 transformers-4.57.1 trec-car-tools-2.6 tzdata-2025.2 unlzw3-0.2.3 urllib3-2.5.0 warc3-wet-0.2.5 warc3-wet-clueweb09-0.2.5 xxhash-3.6.0 yarl-1.22.0 zlib-state-0.1.10

# %%
from FlagEmbedding import BGEM3FlagModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from FlagEmbedding import BGEM3FlagModel
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/FlagEmbedding/__init__.py:2
#       1 from .abc.inference import *
# ----> 2 from .inference import *
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/FlagEmbedding/inference/__init__.py:1
# ----> 1 from .auto_embedder import FlagAutoModel
#       2 from .auto_reranker import FlagAutoReranker
#       3 from .embedder import (
#       4     FlagModel, BGEM3FlagModel,
#       5     FlagICLModel, FlagLLMModel,
#       6     EmbedderModelClass
#       7 )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/FlagEmbedding/inference/auto_embedder.py:5
#       2 import logging
#       3 from typing import List, Union, Optional
# ----> 5 from FlagEmbedding.inference.embedder.model_mapping import (
#       6     EmbedderModelClass,
#       7     AUTO_EMBEDDER_MAPPING, EMBEDDER_CLASS_MAPPING
#       8 )
#      10 logger = logging.getLogger(__name__)
#      13 class FlagAutoModel:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/FlagEmbedding/inference/embedder/__init__.py:1
# ----> 1 from .encoder_only import FlagModel, BGEM3FlagModel
#       2 from .decoder_only import FlagICLModel, FlagLLMModel
#       3 from .model_mapping import EmbedderModelClass
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/FlagEmbedding/inference/embedder/encoder_only/__init__.py:2
#       1 from .base import BaseEmbedder as FlagModel
# ----> 2 from .m3 import M3Embedder as BGEM3FlagModel
#       4 __all__ = [
#       5     "FlagModel",
#       6     "BGEM3FlagModel",
#       7 ]
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/FlagEmbedding/inference/embedder/encoder_only/m3.py:13
#      10 from typing import Any, List, Union, Dict, Literal, Tuple, Optional
#      12 from FlagEmbedding.abc.inference import AbsEmbedder
# ---> 13 from FlagEmbedding.finetune.embedder.encoder_only.m3 import (
#      14     EncoderOnlyEmbedderM3ModelForInference, EncoderOnlyEmbedderM3Runner
#      15 )
#      17 logger = logging.getLogger(__name__)
#      20 class M3Embedder(AbsEmbedder):
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/FlagEmbedding/finetune/embedder/encoder_only/m3/__init__.py:1
# ----> 1 from FlagEmbedding.abc.finetune.embedder import AbsEmbedderDataArguments as EncoderOnlyEmbedderM3DataArguments
#       3 from .arguments import EncoderOnlyEmbedderM3ModelArguments, EncoderOnlyEmbedderM3TrainingArguments
#       4 from .modeling import EncoderOnlyEmbedderM3Model, EncoderOnlyEmbedderM3ModelForInference
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/FlagEmbedding/abc/finetune/embedder/__init__.py:6
#       1 from .AbsArguments import (
#       2     AbsEmbedderDataArguments,
#       3     AbsEmbedderModelArguments,
#       4     AbsEmbedderTrainingArguments,
#       5 )
# ----> 6 from .AbsDataset import (
#       7     AbsEmbedderCollator, AbsEmbedderSameDatasetCollator,
#       8     AbsEmbedderSameDatasetTrainDataset,
#       9     AbsEmbedderTrainDataset,
#      10     EmbedderTrainerCallbackForDataRefresh,
#      11 )
#      12 from .AbsModeling import AbsEmbedderModel, EmbedderOutput
#      13 from .AbsTrainer import AbsEmbedderTrainer
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/FlagEmbedding/abc/finetune/embedder/AbsDataset.py:5
#       3 import random
#       4 import logging
# ----> 5 import datasets
#       6 import numpy as np
#       7 import torch.distributed as dist
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/datasets/__init__.py:17
#       1 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "4.4.1"
# ---> 17 from .arrow_dataset import Column, Dataset
#      18 from .arrow_reader import ReadInstruction
#      19 from .builder import ArrowBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/datasets/arrow_dataset.py:78
#      76 from . import config
#      77 from .arrow_reader import ArrowReader
# ---> 78 from .arrow_writer import ArrowWriter, OptimizedTypedSequence
#      79 from .data_files import sanitize_patterns
#      80 from .download.streaming_download_manager import xgetsize
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/datasets/arrow_writer.py:28
#      25 from fsspec.core import url_to_fs
#      27 from . import config
# ---> 28 from .features import Audio, Features, Image, Pdf, Value, Video
#      29 from .features.features import (
#      30     FeatureType,
#      31     List,
#    (...)     39     to_pyarrow_listarray,
#      40 )
#      41 from .filesystems import is_remote_filesystem
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/datasets/features/__init__.py:20
#       1 __all__ = [
#       2     "Audio",
#       3     "Array2D",
#    (...)     18     "Nifti",
#      19 ]
# ---> 20 from .audio import Audio
#      21 from .features import Array2D, Array3D, Array4D, Array5D, ClassLabel, Features, LargeList, List, Sequence, Value
#      22 from .image import Image
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/datasets/features/audio.py:13
#      11 from ..download.download_config import DownloadConfig
#      12 from ..table import array_cast
# ---> 13 from ..utils.file_utils import is_local_path, xopen
#      14 from ..utils.py_utils import no_op_if_value_is_null, string_to_dict
#      17 if TYPE_CHECKING:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/datasets/utils/file_utils.py:44
#      42 from . import _tqdm, logging
#      43 from ._filelock import FileLock
# ---> 44 from .extract import ExtractManager
#      45 from .track import TrackedIterableFromGenerator
#      48 try:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/datasets/utils/extract.py:3
#       1 import bz2
#       2 import gzip
# ----> 3 import lzma
#       4 import os
#       5 import shutil
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/lzma.py:27
#      25 import io
#      26 import os
# ---> 27 from _lzma import *
#      28 from _lzma import _encode_filter_properties, _decode_filter_properties
#      29 import _compression
#
# ModuleNotFoundError: No module named '_lzma'

# %%
# !python -m pip install --upgrade pip
# !apt install liblzma-dev
# Out:
# Requirement already satisfied: pip in /Users/taeni/.pyenv/versions/3.11.9/lib/python3.11/site-packages (25.3)
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.

# %%
model = BGEM3FlagModel("BAAI/bge-m3", use_fp16=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model = BGEM3FlagModel("BAAI/bge-m3", use_fp16=False)
#
# NameError: name 'BGEM3FlagModel' is not defined
